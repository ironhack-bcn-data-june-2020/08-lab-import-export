# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %% [markdown]
# # Challenge 1 - Working with JSON files
#
# Import the pandas library

# %%
# Your import here:

import pandas as pd

# %% [markdown]
# ####  After importing pandas, let's find a dataset. In this lesson we will be working with a NASA dataset.
#
# Run the code in the cell below to load the dataset containing information about asteroids that have landed on earth. This piece of code helps us open the URL for the dataset and deocde the data using UTF-8.

# %%
# Run this code

from urllib.request import urlopen
import json

response = urlopen("https://data.nasa.gov/resource/y77d-th95.json")
json_data = response.read().decode('utf-8', 'replace')

# %% [markdown]
# In the next cell, load the data in `json_data` and load it into a pandas dataframe. Name the dataframe `nasa`.

# %%
# Your code here:
from pandas import DataFrame
nasa = pd.read_json("https://data.nasa.gov/resource/y77d-th95.json")
print(nasa)
# Out:
#           name     id nametype               recclass      mass  fall  \
# 0       Aachen      1    Valid                     L5      21.0  Fell
# 1       Aarhus      2    Valid                     H6     720.0  Fell
# 2         Abee      6    Valid                    EH4  107000.0  Fell
# 3     Acapulco     10    Valid            Acapulcoite    1914.0  Fell
# 4      Achiras    370    Valid                     L6     780.0  Fell
# ..         ...    ...      ...                    ...       ...   ...
# 995   Tirupati  24009    Valid                     H6     230.0  Fell
# 996    Tissint  54823    Valid  Martian (shergottite)    7000.0  Fell
# 997      Tjabe  24011    Valid                     H6   20000.0  Fell
# 998   Tjerebon  24012    Valid                     L5   16500.0  Fell
# 999  Tomakovka  24019    Valid                    LL6     600.0  Fell
#
#                         year    reclat    reclong  \
# 0    1880-01-01T00:00:00.000  50.77500    6.08333
# 1    1951-01-01T00:00:00.000  56.18333   10.23333
# 2    1952-01-01T00:00:00.000  54.21667 -113.00000
# 3    1976-01-01T00:00:00.000  16.88333  -99.90000
# 4    1902-01-01T00:00:00.000 -33.16667  -64.95000
# ..                       ...       ...        ...
# 995  1934-01-01T00:00:00.000  13.63333   79.41667
# 996  2011-01-01T00:00:00.000  29.48195   -7.61123
# 997  1869-01-01T00:00:00.000  -7.08333  111.53333
# 998  1922-01-01T00:00:00.000  -6.66667  106.58333
# 999  1905-01-01T00:00:00.000  47.85000   34.76667
#
#                                            geolocation  \
# 0    {'type': 'Point', 'coordinates': [6.08333, 50....
# 1    {'type': 'Point', 'coordinates': [10.23333, 56...
# 2    {'type': 'Point', 'coordinates': [-113, 54.216...
# 3    {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4    {'type': 'Point', 'coordinates': [-64.95, -33....
# ..                                                 ...
# 995  {'type': 'Point', 'coordinates': [79.41667, 13...
# 996  {'type': 'Point', 'coordinates': [-7.61123, 29...
# 997  {'type': 'Point', 'coordinates': [111.53333, -...
# 998  {'type': 'Point', 'coordinates': [106.58333, -...
# 999  {'type': 'Point', 'coordinates': [34.76667, 47...
#
#      :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ..                           ...                          ...
# 995                          NaN                          NaN
# 996                          NaN                          NaN
# 997                          NaN                          NaN
# 998                          NaN                          NaN
# 999                          NaN                          NaN
#
# [1000 rows x 12 columns]

# %% [markdown]
# Now that we have loaded the data, let's examine it using the `head()` function.

# %%
# Your code here:
nasa.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN

# %% [markdown]
# #### The `value_counts()` function is commonly used in pandas to find the frequency of every value in a column.
#
# In the cell below, use the `value_counts()` function to determine the frequency of all types of asteroid landings by applying the function to the `fall` column.

# %%
# Your code here:
nasa['fall'].value_counts()
# Out:
# Fell     996
# Found      4
# Name: fall, dtype: int64

# %% [markdown]
# Finally, let's save the dataframe as a json file again. Since we downloaded the file from an online source, the goal of saving the dataframe is to have a local copy. Save the dataframe using the `orient=records` argument and name the file `nasa.json`.

# %%
# Your code here:
nasa.to_json("C:\\Users\\AaronElias\\Desktop\\Github")

#no pude entender cual era el error
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-53-f115d2876959> in <module>
#       1 # Your code here:
# ----> 2 nasa.to_json("C:\\Users\\AaronElias\\Desktop\\Github")
#       3
#       4 #no pude entender cual era el error
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#    2362             compression=compression,
#    2363             index=index,
# -> 2364             indent=indent,
#    2365         )
#    2366
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#      90
#      91     if isinstance(path_or_buf, str):
# ---> 92         fh, handles = get_handle(path_or_buf, "w", compression=compression)
#      93         try:
#      94             fh.write(s)
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429         elif is_text:
#     430             # No explicit encoding
# --> 431             f = open(path_or_buf, mode, errors="replace", newline="")
#     432         else:
#     433             # Binary mode
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\AaronElias\\Desktop\\Github'

# %% [markdown]
# # Challenge 2 - Working with CSV and Other Separated Files
#
# csv files are more commonly used as dataframes. In the cell below, load the file from the URL provided using the `read_csv()` function in pandas. Starting version 0.19 of pandas, you can load a csv file into a dataframe directly from a URL without having to load the file first like we did with the JSON URL. The dataset we will be using contains informtaions about NASA shuttles.
#
# In the cell below, we define the column names and the URL of the data. Following this cell, read the tst file to a variable called `shuttle`. Since the file does not contain the column names, you must add them yourself using the column names declared in `cols` using the `names` argument. Additionally, a tst file is space separated, make sure you pass ` sep=' '` to the function.

# %%
# Run this code:

cols = ['time', 'rad_flow', 'fpv_close', 'fpv_open', 'high', 'bypass', 'bpv_close', 'bpv_open', 'class']
tst_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/shuttle/shuttle.tst'

# %%
# Your code here:
import csv
df = pd.read_csv(tst_url)
shuttle =DataFrame(df,columns = ['time', 'rad_flow', 'fpv_close', 'fpv_open', 'high', 'bypass', 'bpv_close', 'bpv_open', 'class'])

# %% [markdown]
# Let's verify that this worked by looking at the `head()` function.

# %%
# Your code here:

shuttle.head()
# Out:
#    time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 0   NaN       NaN        NaN       NaN   NaN     NaN        NaN       NaN
# 1   NaN       NaN        NaN       NaN   NaN     NaN        NaN       NaN
# 2   NaN       NaN        NaN       NaN   NaN     NaN        NaN       NaN
# 3   NaN       NaN        NaN       NaN   NaN     NaN        NaN       NaN
# 4   NaN       NaN        NaN       NaN   NaN     NaN        NaN       NaN
#
#    class
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# To make life easier for us, let's turn this dataframe into a comma separated file by saving it using the `to_csv()` function. Save `shuttle` into the file `shuttle.csv` and ensure the file is comma separated and that we are not saving the index column.

# %%
# Your code here:
shuttle.to_csv(index=False)
# Out:
# 'time,rad_flow,fpv_close,fpv_open,high,bypass,bpv_close,bpv_open,class\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,,,,,,,,\r\n,, ...

# %% [markdown]
# # Challenge 3 - Working with Excel Files
#
# We can also use pandas to convert excel spreadsheets to dataframes. Let's use the `read_excel()` function. In this case, `astronauts.xls` is in the same folder that contains this notebook. Read this file into a variable called `astronaut`.
#
# Note: Make sure to install the `xlrd` library if it is not yet installed.

# %%
# Your code here:
import xlrd

astronaut = pd.read_excel("C:\\Users\\AaronElias\\Desktop\\Github\\Prueba-Aaron\\08-lab-import-export\\your-code\\astronauts.xls", header=None)

# %% [markdown]
# Use the `head()` function to inspect the dataframe.

# %%
# Your code here:

astronaut.head()
# Out:
#                  0     1      2        3                    4              5   \
# 0              Name  Year  Group   Status           Birth Date    Birth Place
# 1   Joseph M. Acaba  2004     19   Active  1967-05-17 00:00:00  Inglewood, CA
# 2    Loren W. Acton   NaN    NaN  Retired  1936-03-07 00:00:00   Lewiston, MT
# 3  James C. Adamson  1984     10  Retired  1946-03-03 00:00:00     Warsaw, NY
# 4   Thomas D. Akers  1987     12  Retired  1951-05-20 00:00:00  St. Louis, MO
#
#        6                                                  7   \
# 0  Gender                                         Alma Mater
# 1    Male  University of California-Santa Barbara; Univer...
# 2    Male   Montana State University; University of Colorado
# 3    Male          US Military Academy; Princeton University
# 4    Male                       University of Missouri-Rolla
#
#                     8                      9              10  \
# 0  Undergraduate Major         Graduate Major  Military Rank
# 1              Geology                Geology            NaN
# 2  Engineering Physics          Solar Physics            NaN
# 3          Engineering  Aerospace Engineering        Colonel
# 4  Applied Mathematics    Applied Mathematics        Colonel
#
#                        11             12                 13           14  \
# 0         Military Branch  Space Flights  Space Flight (hr)  Space Walks
# 1                     NaN              2               3307            2
# 2                     NaN              1                190            0
# 3       US Army (Retired)              2                334            0
# 4  US Air Force (Retired)              4                814            4
#
#                  15                                                 16  \
# 0  Space Walks (hr)                                           Missions
# 1                13             STS-119 (Discovery), ISS-31/32 (Soyuz)
# 2                 0                              STS 51-F (Challenger)
# 3                 0               STS-28 (Columbia), STS-43 (Atlantis)
# 4                29  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...
#
#            17             18
# 0  Death Date  Death Mission
# 1         NaN            NaN
# 2         NaN            NaN
# 3         NaN            NaN
# 4         NaN            NaN

# %% [markdown]
# Use the `value_counts()` function to find the most popular undergraduate major among all astronauts.

# %%
# Your code here:

astronaut[8].value_counts()
# Out:
# Physics                                          35
# Aerospace Engineering                            33
# Mechanical Engineering                           30
# Aeronautical Engineering                         28
# Electrical Engineering                           23
#                                                  ..
# Mathematics; Russian                              1
# Business Management; Aeronautical Engineering     1
# Mathematics & Economics                           1
# Biology & Psychology                              1
# Animal Science                                    1
# Name: 8, Length: 84, dtype: int64

# %% [markdown]
# Due to all the commas present in the cells of this file, let's save it as a tab separated csv file. In the cell below, save `astronaut` as a tab separated file using the `to_csv` function. Call the file `astronaut.csv` and remember to remove the index column.

# %%
# Your code here:
astronaut.to_excel('example.xlsx', sheet_name='example', index=False)

# %% [markdown]
# # Bonus Challenge - Fertility Dataset
#
# Visit the following [URL](https://archive.ics.uci.edu/ml/datasets/Fertility) and retrieve the dataset as well as the column headers. Determine the correct separator and read the file into a variable called `fertility`. Examine the dataframe using the `head()` function.

# %%
# Your code here:
